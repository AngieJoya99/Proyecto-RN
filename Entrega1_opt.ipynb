# %% [markdown]
# **Angie Carolina Joya Duarte - 2322609**
#
# **Sheila Marcela Valencia Chito - 2243011**

# %% [markdown]
# Tiene  como  objetivo  el  entrenamiento  y  evaluación  de  un  modelo  con  el  dataset
# seleccionado usando una arquitectura de Perceptrón Multicapa. condiciones de entrenamiento, evaluación, conclusiones

# %% [markdown]
# # Entrega 1 - Perceptrón Multicapa

# %% [markdown]
# Se escogió para este trabajo el dataset "Twitter US Airline Sentiment"

# %% [markdown]
# ## Importación del dataset

# %% [markdown]
# Importamos las librerías

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
from imblearn.under_sampling import NearMiss
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import RegexpTokenizer
import re

# %% [markdown]
# Importamos el dataset y lo almacenamos como un dataframe de pandas. Verificamos que no hayan datos faltantes y convertimos la salidas en números usando one hot encoding

# %%
path = os.path.join(os.getcwd(), "Tweets.csv")
dataset = pd.read_csv(path, usecols=[1, 5, 10])

print("Clasificación Original: ", dataset.airline_sentiment.unique(),"\n")

#Se reemplaza negative por 0, neutral por 1 y positive por 2
dataset["airline_sentiment"] = dataset["airline_sentiment"].replace({"negative" : 0, "neutral" : 1, "positive" : 2}).astype(int)

#dataset.describe(include='all')
dataset.info()
print("\nAerolíneas: ", dataset.airline.unique())
print("Clasificación one hot encoder: ", dataset.airline_sentiment.unique())
# Out:
# Clasificación Original:  ['neutral' 'positive' 'negative']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   airline_sentiment  14640 non-null  int64
#  1   airline            14640 non-null  object
#  2   text               14640 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 343.3+ KB
#
# Aerolíneas:  ['Virgin America' 'United' 'Southwest' 'Delta' 'US Airways' 'American']
# Clasificación one hot encoder:  [1 2 0]
# C:\Users\Univalle\AppData\Local\Temp\ipykernel_15604\879290016.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset["airline_sentiment"] = dataset["airline_sentiment"].replace({"negative" : 0, "neutral" : 1, "positive" : 2}).astype(int)

# %%
graphAirline = sns.countplot(x="airline", hue="airline", data=dataset, palette="Set2", legend=False)
total = len(dataset)

for p in graphAirline.patches:
    count = p.get_height() #frecuencia absoluta
    percent = 100 * count / total #frecuencia relativa
    
    graphAirline.annotate(f'{percent:.1f}%', # formato de texto
        (p.get_x() + p.get_width() / 2., count/2),  #posición
        ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 5),
        textcoords='offset points')
    
graphAirline.set_xlabel("Aerolínea")
graphAirline.set_ylabel("Instancias")
graphAirline.set_title("Distribución Porcentual de las Aerolíneas")


plt.show()

# %%
graphOutput = sns.countplot(x="airline_sentiment", hue="airline_sentiment",  data=dataset, palette="Set2", legend=False)
total = len(dataset)

for p in graphOutput.patches:
    count = p.get_height() #frecuencia absoluta
    percent = 100 * count / total #frecuencia relativa
    
    graphOutput.annotate(f'{percent:.1f}%', # formato de texto
        (p.get_x() + p.get_width() / 2., count/2),  #posición
        ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 5),
        textcoords='offset points')
    
ticks = graphOutput.get_xticks()
graphOutput.set_xticks(ticks)
graphOutput.set_xticklabels(["Negativo", "Neutro", "Positivo"])
graphOutput.set_xlabel("Sentimiento")
graphOutput.set_ylabel("Instancias")
graphOutput.set_title("Distribución Porcentual de los Sentimientos")

plt.show()

# %% [markdown]
# Como el dataset está compuesto por cadenas de texto, será pre procesado antes de iniciar el entrenamiento

# %%
nltk.download('stopwords')
palVacias = set(stopwords.words('english')) 
palRaiz = SnowballStemmer('english')
tokenizador = RegexpTokenizer(r"\b\w+(?:'\w+)?\b")
usuarios = r"@\w*"
hashtags = r"#(\w+)"
links = links = r"http\S+|www\.\S+"

def preprocesamiento (tweet, stem=True):
    tweet = re.sub(usuarios, "", tweet)
    tweet = re.sub(hashtags, r"\1", tweet)
    tweet = re.sub(r"\b(\w+)n't\b", "not", tweet, flags=re.IGNORECASE) #Para las negaciones
    tweet = re.sub(links, "", tweet)
    
    palabras = tokenizador.tokenize(tweet)
    texto = []
    for palabra in palabras: 
        palabra_lower = palabra.lower()
        # Conserva "no" aunque sea stopword
        if palabra_lower == "not" or palabra_lower == "no" or palabra_lower not in palVacias:
            if stem:
                texto.append(palRaiz.stem(palabra).lower())
            else:
                texto.append(palabra_lower)
    
    return tokenizador.tokenize(" ".join(texto))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Univalle\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Los enlaces se muestran como palabras: 'http', 'co', 'vhp2gtdwpk'
print(f"Texto Original: {dataset.text[39]}")
print(f"\nTexto Preprocesado: {preprocesamiento(dataset.text[39])}")
# Out:
# Texto Original: @VirginAmerica Your chat support is not working on your site: http://t.co/vhp2GtDWPk
#
# Texto Preprocesado: ['chat', 'support', 'not', 'work', 'site']

# %%
#Aplicar preprocesamiento a todo el dataset
dataset["token"] = dataset.text.map(preprocesamiento)
dataset.head()
# Out:
#    airline_sentiment         airline  \
# 0                  1  Virgin America
# 1                  2  Virgin America
# 2                  1  Virgin America
# 3                  0  Virgin America
# 4                  0  Virgin America
#
#                                                 text  \
# 0                @VirginAmerica What @dhepburn said.
# 1  @VirginAmerica plus you've added commercials t...
# 2  @VirginAmerica I didn't today... Must mean I n...
# 3  @VirginAmerica it's really aggressive to blast...
# 4  @VirginAmerica and it's a really big bad thing...
#
#                                                token
# 0                                             [said]
# 1                [plus, ad, commerci, experi, tacki]
# 2  [not, today, must, mean, need, take, anoth, trip]
# 3  [realli, aggress, blast, obnoxi, entertain, gu...
# 4                          [realli, big, bad, thing]

# %%
vectorizador = TfidfVectorizer(
  tokenizer=lambda x: x, 
    preprocessor=lambda x: x, 
    token_pattern=None,
    ngram_range=(1,2),  # unigrams + bigrams
    min_df=3, # ignora palabras rarísimas
    max_df=0.9
  )
matriz = vectorizador.fit_transform(dataset["token"])

from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler

svd = TruncatedSVD(n_components=300, random_state=42)
matriz_svd = svd.fit_transform(matriz)

# Escalar (normalización)
scaler = StandardScaler()
matriz_svd = scaler.fit_transform(matriz_svd)

dataset["rep"] = matriz_svd.tolist()
dataset.head()
# Out:
#    airline_sentiment         airline  \
# 0                  1  Virgin America
# 1                  2  Virgin America
# 2                  1  Virgin America
# 3                  0  Virgin America
# 4                  0  Virgin America
#
#                                                 text  \
# 0                @VirginAmerica What @dhepburn said.
# 1  @VirginAmerica plus you've added commercials t...
# 2  @VirginAmerica I didn't today... Must mean I n...
# 3  @VirginAmerica it's really aggressive to blast...
# 4  @VirginAmerica and it's a really big bad thing...
#
#                                                token  \
# 0                                             [said]
# 1                [plus, ad, commerci, experi, tacki]
# 2  [not, today, must, mean, need, take, anoth, trip]
# 3  [realli, aggress, blast, obnoxi, entertain, gu...
# 4                          [realli, big, bad, thing]
#
#                                                  rep
# 0  [-0.4436108992312125, -0.7270816566788405, -0....
# 1  [-0.4400674522902267, -0.817444374400045, -0.0...
# 2  [-0.20420856435639567, 0.3509935026227756, -0....
# 3  [-0.4197145267098829, -0.6603471258744055, -0....
# 4  [-0.38259301701733595, -0.603346062784163, -0....

# %% [markdown]
# Ahora, vamos a revisar la revisión porcentual de los datos para asegurarnos de que el conjunto sea representativo

# %% [markdown]
# La distribución de los datos no está balanceada. La aerolínea Virgin América tiene muchas menos instancias que las demás, y United tiene muchas más, así que implementamos la técnica del Submuestreo Near Miss para equilibrar los datos.

# %%
submuestreo = NearMiss()
x = np.vstack(dataset["rep"].values)
y = dataset["airline_sentiment"].values

xBal, yBal = submuestreo.fit_resample(x, y)
indicesBal = submuestreo.sample_indices_

datasetBal = dataset.iloc[indicesBal].copy().reset_index(drop=True)
datasetBal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7089 entries, 0 to 7088
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   airline_sentiment  7089 non-null   int64
#  1   airline            7089 non-null   object
#  2   text               7089 non-null   object
#  3   token              7089 non-null   object
#  4   rep                7089 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 277.0+ KB

# %%
graphOutput = sns.countplot(x="airline_sentiment", hue="airline_sentiment",  data=datasetBal, palette="Set2", legend=False)
total = len(datasetBal)

for p in graphOutput.patches:
    count = p.get_height() #frecuencia absoluta
    percent = 100 * count / total #frecuencia relativa
    
    graphOutput.annotate(f'{percent:.1f}%', # formato de texto
        (p.get_x() + p.get_width() / 2., count/2),  #posición
        ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 5),
        textcoords='offset points')
    
ticks = graphOutput.get_xticks()
graphOutput.set_xticks(ticks)
graphOutput.set_xticklabels(["Negativo", "Neutro", "Positivo"])
graphOutput.set_xlabel("Sentimiento")
graphOutput.set_ylabel("Instancias")
graphOutput.set_title("Distribución Porcentual de los Sentimientos del dataset Balanceado")

plt.show()

# %%
n = len(datasetBal)
cTrain = int(n*0.7) # 70% para entrenar y 30% para probar
cTest = n-cTrain
print(f"N = {n} | Tamaño entrenamiento = {cTrain} | Tamaño prueba = {cTest}")
trainData, testData = train_test_split(datasetBal, train_size=cTrain, test_size=cTest)
testData.head()
# Out:
# N = 7089 | Tamaño entrenamiento = 4962 | Tamaño prueba = 2127
#       airline_sentiment     airline  \
# 6984                  2    American
# 848                   0  US Airways
# 483                   0      United
# 1803                  0  US Airways
# 5576                  2   Southwest
#
#                                                    text  \
# 6984  @AmericanAir Not necessary.  I am confident th...
# 848   @USAirways it was your fault the flight was de...
# 483   @united your staff at LaGuardia and Lagos, Nig...
# 1803  @USAirways , I am embarrassed for us air and t...
# 5576  @SouthwestAir I made it! Heading to Denver, an...
#
#                                                   token  \
# 6984  [not, necessari, confid, excel, flight, staff,...
# 848   [fault, flight, delay, begin, not, check, bag,...
# 483   [staff, laguardia, lago, nigeria, unprofession...
# 1803  [embarrass, us, air, inabl, manag, weather, de...
# 5576  [made, head, denver, employe, realli, pleasant...
#
#                                                     rep
# 6984  [-0.2068313749118599, 0.4449319524397647, -0.1...
# 848   [-0.08708820206094756, 1.1170074990462044, -0....
# 483   [-0.2530001048243748, 0.09098014427460265, -0....
# 1803  [-0.34644668418001245, -0.2824187189875933, -0...
# 5576  [0.944034283258611, -1.0120004628704102, -0.06...

# %%
# cantClases = 3
# sizeVocab = np.vstack(trainData.rep.values).shape[1]

# modelo = keras.Sequential([
#     layers.Input(shape=(sizeVocab,)),
#     layers.Dense(64, activation="relu", kernel_regularizer=regularizers.l2(0.001),),
#     layers.Dropout(0.4),
#     layers.Dense(32, activation="relu", kernel_regularizer=regularizers.l2(0.001),),
#     layers.Dropout(0.2),
#     layers.Dense(cantClases, activation="softmax")
# ])  
# opt = Adam(learning_rate=0.00001)
# modelo.compile(optimizer="adagrad", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

cantClases = 3
sizeVocab = np.vstack(trainData.rep.values).shape[1]

modelo = keras.Sequential([
    layers.Input(shape=(sizeVocab,)),
    layers.Dense(64, activation="relu", kernel_regularizer=regularizers.l2(0.0001),),
    layers.Dropout(0.3),
    layers.Dense(32, activation="relu", kernel_regularizer=regularizers.l2(0.0001),),
    layers.Dropout(0.2),
    layers.Dense(cantClases, activation="softmax")
])  
opt = Adam(learning_rate=0.00001)
modelo.compile(optimizer="adagrad", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
def entrenamiento (xTrain, yTrain, xTest, yTest, modelo, epocas, lote, es, rlr):
    history = modelo.fit(
        xTrain, yTrain,
        validation_data = (xTest, yTest),
        epochs = epocas,
        callbacks=[es, rlr],
        batch_size = lote,
        verbose = 1
    )
    return history

# %%
xTrain = np.array(trainData["rep"].to_list(), dtype="float32")
yTrain = trainData.airline_sentiment.values
xTest = np.array(testData["rep"].to_list(), dtype="float32")
yTest = testData.airline_sentiment.values
epocas = 200
lote = 32

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

es = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
rlr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-7)

resultado = entrenamiento(xTrain, yTrain, xTest, yTest, modelo, epocas, lote, es, rlr)

resultados = {
    "Época": ["Primera", "Última"],
    "Loss": [resultado.history["loss"][0], resultado.history["loss"][-1]],
    "Val_Loss": [resultado.history["val_loss"][0], resultado.history["val_loss"][-1]],
    "Accuracy": [resultado.history["accuracy"][0], resultado.history["accuracy"][-1]],
    "Val_Accuracy": [resultado.history["val_accuracy"][0], resultado.history["val_accuracy"][-1]],
}

tabla = pd.DataFrame(resultados)
print(tabla)
# Out:
# Epoch 1/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3517 - loss: 1.3683 - val_accuracy: 0.3677 - val_loss: 1.1704 - learning_rate: 0.0010
# Epoch 2/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3609 - loss: 1.2712 - val_accuracy: 0.3822 - val_loss: 1.1402 - learning_rate: 0.0010
# Epoch 3/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3759 - loss: 1.2518 - val_accuracy: 0.3963 - val_loss: 1.1210 - learning_rate: 0.0010
# Epoch 4/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3843 - loss: 1.2244 - val_accuracy: 0.4024 - val_loss: 1.1062 - learning_rate: 0.0010
# Epoch 5/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3918 - loss: 1.1918 - val_accuracy: 0.4133 - val_loss: 1.0943 - learning_rate: 0.0010
# Epoch 6/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4039 - loss: 1.1814 - val_accuracy: 0.4250 - val_loss: 1.0844 - learning_rate: 0.0010
# Epoch 7/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4033 - loss: 1.1670 - val_accuracy: 0.4321 - val_loss: 1.0761 - learning_rate: 0.0010
# Epoch 8/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4186 - loss: 1.1485 - val_accuracy: 0.4358 - val_loss: 1.0687 - learning_rate: 0.0010
# Epoch 9/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4226 - loss: 1.1397 - val_accuracy: 0.4429 - val_loss: 1.0618 - learning_rate: 0.0010
# Epoch 10/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4152 - loss: 1.1338 - val_accuracy: 0.4452 - val_loss: 1.0555 - learning_rate: 0.0010
# Epoch 11/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4194 - loss: 1.1303 - val_accuracy: 0.4490 - val_loss: 1.0496 - learning_rate: 0.0010
# Epoch 12/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4339 - loss: 1.1093 - val_accuracy: 0.4542 - val_loss: 1.0446 - learning_rate: 0.0010
# Epoch 13/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4399 - loss: 1.1102 - val_accuracy: 0.4607 - val_loss: 1.0398 - learning_rate: 0.0010
# Epoch 14/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4454 - loss: 1.0905 - val_accuracy: 0.4659 - val_loss: 1.0353 - learning_rate: 0.0010
# Epoch 15/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4464 - loss: 1.0955 - val_accuracy: 0.4711 - val_loss: 1.0309 - learning_rate: 0.0010
# Epoch 16/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4508 - loss: 1.0932 - val_accuracy: 0.4730 - val_loss: 1.0267 - learning_rate: 0.0010
# Epoch 17/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4504 - loss: 1.0843 - val_accuracy: 0.4767 - val_loss: 1.0228 - learning_rate: 0.0010
# Epoch 18/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4577 - loss: 1.0727 - val_accuracy: 0.4805 - val_loss: 1.0191 - learning_rate: 0.0010
# Epoch 19/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4514 - loss: 1.0722 - val_accuracy: 0.4847 - val_loss: 1.0157 - learning_rate: 0.0010
# Epoch 20/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4601 - loss: 1.0682 - val_accuracy: 0.4871 - val_loss: 1.0123 - learning_rate: 0.0010
# Epoch 21/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4657 - loss: 1.0563 - val_accuracy: 0.4913 - val_loss: 1.0093 - learning_rate: 0.0010
# Epoch 22/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4698 - loss: 1.0604 - val_accuracy: 0.4941 - val_loss: 1.0064 - learning_rate: 0.0010
# Epoch 23/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4706 - loss: 1.0499 - val_accuracy: 0.4979 - val_loss: 1.0034 - learning_rate: 0.0010
# Epoch 24/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4827 - loss: 1.0454 - val_accuracy: 0.5007 - val_loss: 1.0005 - learning_rate: 0.0010
# Epoch 25/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4794 - loss: 1.0434 - val_accuracy: 0.5063 - val_loss: 0.9978 - learning_rate: 0.0010
# Epoch 26/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4881 - loss: 1.0368 - val_accuracy: 0.5078 - val_loss: 0.9950 - learning_rate: 0.0010
# Epoch 27/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4911 - loss: 1.0290 - val_accuracy: 0.5106 - val_loss: 0.9925 - learning_rate: 0.0010
# Epoch 28/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4821 - loss: 1.0386 - val_accuracy: 0.5106 - val_loss: 0.9899 - learning_rate: 0.0010
# Epoch 29/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4891 - loss: 1.0310 - val_accuracy: 0.5162 - val_loss: 0.9874 - learning_rate: 0.0010
# Epoch 30/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4958 - loss: 1.0258 - val_accuracy: 0.5181 - val_loss: 0.9854 - learning_rate: 0.0010
# Epoch 31/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4962 - loss: 1.0272 - val_accuracy: 0.5233 - val_loss: 0.9831 - learning_rate: 0.0010
# Epoch 32/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4970 - loss: 1.0147 - val_accuracy: 0.5256 - val_loss: 0.9807 - learning_rate: 0.0010
# Epoch 33/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4970 - loss: 1.0170 - val_accuracy: 0.5294 - val_loss: 0.9784 - learning_rate: 0.0010
# Epoch 34/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4998 - loss: 1.0223 - val_accuracy: 0.5317 - val_loss: 0.9762 - learning_rate: 0.0010
# Epoch 35/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5075 - loss: 1.0129 - val_accuracy: 0.5341 - val_loss: 0.9743 - learning_rate: 0.0010
# Epoch 36/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5075 - loss: 1.0074 - val_accuracy: 0.5360 - val_loss: 0.9722 - learning_rate: 0.0010
# Epoch 37/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5054 - loss: 1.0008 - val_accuracy: 0.5393 - val_loss: 0.9701 - learning_rate: 0.0010
# Epoch 38/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5089 - loss: 0.9945 - val_accuracy: 0.5407 - val_loss: 0.9681 - learning_rate: 0.0010
# Epoch 39/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5050 - loss: 1.0075 - val_accuracy: 0.5425 - val_loss: 0.9662 - learning_rate: 0.0010
# Epoch 40/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5151 - loss: 1.0097 - val_accuracy: 0.5435 - val_loss: 0.9644 - learning_rate: 0.0010
# Epoch 41/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5181 - loss: 0.9994 - val_accuracy: 0.5463 - val_loss: 0.9626 - learning_rate: 0.0010
# Epoch 42/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5169 - loss: 0.9936 - val_accuracy: 0.5505 - val_loss: 0.9606 - learning_rate: 0.0010
# Epoch 43/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5157 - loss: 0.9964 - val_accuracy: 0.5515 - val_loss: 0.9589 - learning_rate: 0.0010
# Epoch 44/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5232 - loss: 0.9870 - val_accuracy: 0.5520 - val_loss: 0.9571 - learning_rate: 0.0010
# Epoch 45/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5198 - loss: 0.9931 - val_accuracy: 0.5543 - val_loss: 0.9554 - learning_rate: 0.0010
# Epoch 46/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5333 - loss: 0.9759 - val_accuracy: 0.5567 - val_loss: 0.9535 - learning_rate: 0.0010
# Epoch 47/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5210 - loss: 0.9860 - val_accuracy: 0.5571 - val_loss: 0.9519 - learning_rate: 0.0010
# Epoch 48/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5252 - loss: 0.9815 - val_accuracy: 0.5590 - val_loss: 0.9502 - learning_rate: 0.0010
# Epoch 49/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5254 - loss: 0.9823 - val_accuracy: 0.5604 - val_loss: 0.9484 - learning_rate: 0.0010
# Epoch 50/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5455 - loss: 0.9596 - val_accuracy: 0.5623 - val_loss: 0.9467 - learning_rate: 0.0010
# Epoch 51/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5284 - loss: 0.9759 - val_accuracy: 0.5637 - val_loss: 0.9451 - learning_rate: 0.0010
# Epoch 52/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5294 - loss: 0.9756 - val_accuracy: 0.5656 - val_loss: 0.9435 - learning_rate: 0.0010
# Epoch 53/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5405 - loss: 0.9681 - val_accuracy: 0.5675 - val_loss: 0.9419 - learning_rate: 0.0010
# Epoch 54/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5326 - loss: 0.9745 - val_accuracy: 0.5675 - val_loss: 0.9405 - learning_rate: 0.0010
# Epoch 55/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5514 - loss: 0.9573 - val_accuracy: 0.5679 - val_loss: 0.9391 - learning_rate: 0.0010
# Epoch 56/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5524 - loss: 0.9615 - val_accuracy: 0.5698 - val_loss: 0.9375 - learning_rate: 0.0010
# Epoch 57/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5464 - loss: 0.9590 - val_accuracy: 0.5726 - val_loss: 0.9360 - learning_rate: 0.0010
# Epoch 58/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5443 - loss: 0.9693 - val_accuracy: 0.5736 - val_loss: 0.9344 - learning_rate: 0.0010
# Epoch 59/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5435 - loss: 0.9526 - val_accuracy: 0.5755 - val_loss: 0.9328 - learning_rate: 0.0010
# Epoch 60/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5451 - loss: 0.9572 - val_accuracy: 0.5755 - val_loss: 0.9315 - learning_rate: 0.0010
# Epoch 61/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5494 - loss: 0.9616 - val_accuracy: 0.5787 - val_loss: 0.9300 - learning_rate: 0.0010
# Epoch 62/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5490 - loss: 0.9490 - val_accuracy: 0.5787 - val_loss: 0.9285 - learning_rate: 0.0010
# Epoch 63/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5488 - loss: 0.9460 - val_accuracy: 0.5802 - val_loss: 0.9271 - learning_rate: 0.0010
# Epoch 64/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5597 - loss: 0.9382 - val_accuracy: 0.5820 - val_loss: 0.9256 - learning_rate: 0.0010
# Epoch 65/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5504 - loss: 0.9557 - val_accuracy: 0.5830 - val_loss: 0.9243 - learning_rate: 0.0010
# Epoch 66/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5679 - loss: 0.9344 - val_accuracy: 0.5830 - val_loss: 0.9228 - learning_rate: 0.0010
# Epoch 67/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5593 - loss: 0.9380 - val_accuracy: 0.5844 - val_loss: 0.9215 - learning_rate: 0.0010
# Epoch 68/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5584 - loss: 0.9394 - val_accuracy: 0.5858 - val_loss: 0.9201 - learning_rate: 0.0010
# Epoch 69/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5645 - loss: 0.9404 - val_accuracy: 0.5872 - val_loss: 0.9189 - learning_rate: 0.0010
# Epoch 70/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5617 - loss: 0.9313 - val_accuracy: 0.5872 - val_loss: 0.9175 - learning_rate: 0.0010
# Epoch 71/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5548 - loss: 0.9493 - val_accuracy: 0.5877 - val_loss: 0.9163 - learning_rate: 0.0010
# Epoch 72/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5603 - loss: 0.9347 - val_accuracy: 0.5882 - val_loss: 0.9150 - learning_rate: 0.0010
# Epoch 73/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5530 - loss: 0.9360 - val_accuracy: 0.5914 - val_loss: 0.9138 - learning_rate: 0.0010
# Epoch 74/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5808 - loss: 0.9225 - val_accuracy: 0.5933 - val_loss: 0.9126 - learning_rate: 0.0010
# Epoch 75/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5643 - loss: 0.9350 - val_accuracy: 0.5929 - val_loss: 0.9112 - learning_rate: 0.0010
# Epoch 76/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5774 - loss: 0.9200 - val_accuracy: 0.5943 - val_loss: 0.9101 - learning_rate: 0.0010
# Epoch 77/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5675 - loss: 0.9257 - val_accuracy: 0.5957 - val_loss: 0.9088 - learning_rate: 0.0010
# Epoch 78/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5649 - loss: 0.9290 - val_accuracy: 0.5961 - val_loss: 0.9076 - learning_rate: 0.0010
# Epoch 79/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5762 - loss: 0.9163 - val_accuracy: 0.5971 - val_loss: 0.9063 - learning_rate: 0.0010
# Epoch 80/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5778 - loss: 0.9172 - val_accuracy: 0.5994 - val_loss: 0.9051 - learning_rate: 0.0010
# Epoch 81/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5723 - loss: 0.9186 - val_accuracy: 0.5976 - val_loss: 0.9039 - learning_rate: 0.0010
# Epoch 82/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5784 - loss: 0.9141 - val_accuracy: 0.5966 - val_loss: 0.9028 - learning_rate: 0.0010
# Epoch 83/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5705 - loss: 0.9294 - val_accuracy: 0.5990 - val_loss: 0.9017 - learning_rate: 0.0010
# Epoch 84/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5711 - loss: 0.9173 - val_accuracy: 0.5990 - val_loss: 0.9006 - learning_rate: 0.0010
# Epoch 85/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5689 - loss: 0.9184 - val_accuracy: 0.5994 - val_loss: 0.8996 - learning_rate: 0.0010
# Epoch 86/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5778 - loss: 0.9100 - val_accuracy: 0.6004 - val_loss: 0.8986 - learning_rate: 0.0010
# Epoch 87/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5713 - loss: 0.9115 - val_accuracy: 0.6013 - val_loss: 0.8975 - learning_rate: 0.0010
# Epoch 88/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5820 - loss: 0.9156 - val_accuracy: 0.6027 - val_loss: 0.8963 - learning_rate: 0.0010
# Epoch 89/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5830 - loss: 0.9067 - val_accuracy: 0.6027 - val_loss: 0.8952 - learning_rate: 0.0010
# Epoch 90/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5838 - loss: 0.9090 - val_accuracy: 0.6041 - val_loss: 0.8941 - learning_rate: 0.0010
# Epoch 91/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5897 - loss: 0.9023 - val_accuracy: 0.6041 - val_loss: 0.8931 - learning_rate: 0.0010
# Epoch 92/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5850 - loss: 0.8995 - val_accuracy: 0.6046 - val_loss: 0.8919 - learning_rate: 0.0010
# Epoch 93/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5854 - loss: 0.9005 - val_accuracy: 0.6065 - val_loss: 0.8908 - learning_rate: 0.0010
# Epoch 94/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5836 - loss: 0.9019 - val_accuracy: 0.6074 - val_loss: 0.8897 - learning_rate: 0.0010
# Epoch 95/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5796 - loss: 0.9003 - val_accuracy: 0.6079 - val_loss: 0.8887 - learning_rate: 0.0010
# Epoch 96/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5881 - loss: 0.8972 - val_accuracy: 0.6084 - val_loss: 0.8877 - learning_rate: 0.0010
# Epoch 97/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5887 - loss: 0.8953 - val_accuracy: 0.6084 - val_loss: 0.8867 - learning_rate: 0.0010
# Epoch 98/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5871 - loss: 0.8942 - val_accuracy: 0.6079 - val_loss: 0.8857 - learning_rate: 0.0010
# Epoch 99/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5887 - loss: 0.9012 - val_accuracy: 0.6084 - val_loss: 0.8848 - learning_rate: 0.0010
# Epoch 100/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5893 - loss: 0.8932 - val_accuracy: 0.6093 - val_loss: 0.8837 - learning_rate: 0.0010
# Epoch 101/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5840 - loss: 0.9012 - val_accuracy: 0.6098 - val_loss: 0.8827 - learning_rate: 0.0010
# Epoch 102/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5893 - loss: 0.8935 - val_accuracy: 0.6121 - val_loss: 0.8817 - learning_rate: 0.0010
# Epoch 103/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5812 - loss: 0.8949 - val_accuracy: 0.6117 - val_loss: 0.8807 - learning_rate: 0.0010
# Epoch 104/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5903 - loss: 0.8909 - val_accuracy: 0.6126 - val_loss: 0.8797 - learning_rate: 0.0010
# Epoch 105/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5961 - loss: 0.8901 - val_accuracy: 0.6140 - val_loss: 0.8787 - learning_rate: 0.0010
# Epoch 106/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5887 - loss: 0.8847 - val_accuracy: 0.6140 - val_loss: 0.8778 - learning_rate: 0.0010
# Epoch 107/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6002 - loss: 0.8763 - val_accuracy: 0.6145 - val_loss: 0.8768 - learning_rate: 0.0010
# Epoch 108/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5941 - loss: 0.8878 - val_accuracy: 0.6145 - val_loss: 0.8759 - learning_rate: 0.0010
# Epoch 109/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5899 - loss: 0.8803 - val_accuracy: 0.6164 - val_loss: 0.8749 - learning_rate: 0.0010
# Epoch 110/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6044 - loss: 0.8727 - val_accuracy: 0.6168 - val_loss: 0.8740 - learning_rate: 0.0010
# Epoch 111/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5971 - loss: 0.8780 - val_accuracy: 0.6178 - val_loss: 0.8731 - learning_rate: 0.0010
# Epoch 112/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6028 - loss: 0.8785 - val_accuracy: 0.6182 - val_loss: 0.8722 - learning_rate: 0.0010
# Epoch 113/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5975 - loss: 0.8809 - val_accuracy: 0.6197 - val_loss: 0.8714 - learning_rate: 0.0010
# Epoch 114/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6151 - loss: 0.8695 - val_accuracy: 0.6187 - val_loss: 0.8706 - learning_rate: 0.0010
# Epoch 115/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6098 - loss: 0.8780 - val_accuracy: 0.6201 - val_loss: 0.8697 - learning_rate: 0.0010
# Epoch 116/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6066 - loss: 0.8794 - val_accuracy: 0.6206 - val_loss: 0.8688 - learning_rate: 0.0010
# Epoch 117/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5925 - loss: 0.8820 - val_accuracy: 0.6201 - val_loss: 0.8680 - learning_rate: 0.0010
# Epoch 118/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6127 - loss: 0.8598 - val_accuracy: 0.6211 - val_loss: 0.8671 - learning_rate: 0.0010
# Epoch 119/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5961 - loss: 0.8727 - val_accuracy: 0.6211 - val_loss: 0.8663 - learning_rate: 0.0010
# Epoch 120/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6064 - loss: 0.8736 - val_accuracy: 0.6220 - val_loss: 0.8656 - learning_rate: 0.0010
# Epoch 121/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6102 - loss: 0.8698 - val_accuracy: 0.6220 - val_loss: 0.8647 - learning_rate: 0.0010
# Epoch 122/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6102 - loss: 0.8629 - val_accuracy: 0.6215 - val_loss: 0.8639 - learning_rate: 0.0010
# Epoch 123/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6133 - loss: 0.8673 - val_accuracy: 0.6225 - val_loss: 0.8631 - learning_rate: 0.0010
# Epoch 124/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6114 - loss: 0.8685 - val_accuracy: 0.6239 - val_loss: 0.8623 - learning_rate: 0.0010
# Epoch 125/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6002 - loss: 0.8705 - val_accuracy: 0.6239 - val_loss: 0.8616 - learning_rate: 0.0010
# Epoch 126/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6104 - loss: 0.8608 - val_accuracy: 0.6244 - val_loss: 0.8607 - learning_rate: 0.0010
# Epoch 127/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6064 - loss: 0.8642 - val_accuracy: 0.6239 - val_loss: 0.8598 - learning_rate: 0.0010
# Epoch 128/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6046 - loss: 0.8698 - val_accuracy: 0.6244 - val_loss: 0.8592 - learning_rate: 0.0010
# Epoch 129/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6074 - loss: 0.8625 - val_accuracy: 0.6253 - val_loss: 0.8584 - learning_rate: 0.0010
# Epoch 130/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6139 - loss: 0.8540 - val_accuracy: 0.6253 - val_loss: 0.8575 - learning_rate: 0.0010
# Epoch 131/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6048 - loss: 0.8683 - val_accuracy: 0.6258 - val_loss: 0.8568 - learning_rate: 0.0010
# Epoch 132/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6127 - loss: 0.8633 - val_accuracy: 0.6248 - val_loss: 0.8561 - learning_rate: 0.0010
# Epoch 133/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6145 - loss: 0.8557 - val_accuracy: 0.6258 - val_loss: 0.8553 - learning_rate: 0.0010
# Epoch 134/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6167 - loss: 0.8599 - val_accuracy: 0.6248 - val_loss: 0.8545 - learning_rate: 0.0010
# Epoch 135/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6175 - loss: 0.8587 - val_accuracy: 0.6258 - val_loss: 0.8538 - learning_rate: 0.0010
# Epoch 136/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6227 - loss: 0.8497 - val_accuracy: 0.6253 - val_loss: 0.8530 - learning_rate: 0.0010
# Epoch 137/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6221 - loss: 0.8420 - val_accuracy: 0.6244 - val_loss: 0.8522 - learning_rate: 0.0010
# Epoch 138/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6092 - loss: 0.8567 - val_accuracy: 0.6253 - val_loss: 0.8515 - learning_rate: 0.0010
# Epoch 139/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6191 - loss: 0.8562 - val_accuracy: 0.6253 - val_loss: 0.8509 - learning_rate: 0.0010
# Epoch 140/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6127 - loss: 0.8552 - val_accuracy: 0.6272 - val_loss: 0.8502 - learning_rate: 0.0010
# Epoch 141/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6179 - loss: 0.8518 - val_accuracy: 0.6276 - val_loss: 0.8495 - learning_rate: 0.0010
# Epoch 142/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6185 - loss: 0.8516 - val_accuracy: 0.6281 - val_loss: 0.8489 - learning_rate: 0.0010
# Epoch 143/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6233 - loss: 0.8448 - val_accuracy: 0.6286 - val_loss: 0.8482 - learning_rate: 0.0010
# Epoch 144/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6211 - loss: 0.8559 - val_accuracy: 0.6286 - val_loss: 0.8475 - learning_rate: 0.0010
# Epoch 145/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6197 - loss: 0.8485 - val_accuracy: 0.6291 - val_loss: 0.8467 - learning_rate: 0.0010
# Epoch 146/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6241 - loss: 0.8398 - val_accuracy: 0.6300 - val_loss: 0.8461 - learning_rate: 0.0010
# Epoch 147/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6276 - loss: 0.8369 - val_accuracy: 0.6305 - val_loss: 0.8454 - learning_rate: 0.0010
# Epoch 148/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6262 - loss: 0.8441 - val_accuracy: 0.6309 - val_loss: 0.8448 - learning_rate: 0.0010
# Epoch 149/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6320 - loss: 0.8282 - val_accuracy: 0.6309 - val_loss: 0.8442 - learning_rate: 0.0010
# Epoch 150/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6233 - loss: 0.8366 - val_accuracy: 0.6309 - val_loss: 0.8435 - learning_rate: 0.0010
# Epoch 151/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6181 - loss: 0.8399 - val_accuracy: 0.6314 - val_loss: 0.8428 - learning_rate: 0.0010
# Epoch 152/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6237 - loss: 0.8440 - val_accuracy: 0.6309 - val_loss: 0.8422 - learning_rate: 0.0010
# Epoch 153/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6328 - loss: 0.8385 - val_accuracy: 0.6305 - val_loss: 0.8415 - learning_rate: 0.0010
# Epoch 154/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6237 - loss: 0.8385 - val_accuracy: 0.6319 - val_loss: 0.8409 - learning_rate: 0.0010
# Epoch 155/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6260 - loss: 0.8321 - val_accuracy: 0.6319 - val_loss: 0.8403 - learning_rate: 0.0010
# Epoch 156/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6211 - loss: 0.8329 - val_accuracy: 0.6309 - val_loss: 0.8397 - learning_rate: 0.0010
# Epoch 157/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6258 - loss: 0.8338 - val_accuracy: 0.6309 - val_loss: 0.8391 - learning_rate: 0.0010
# Epoch 158/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6352 - loss: 0.8301 - val_accuracy: 0.6314 - val_loss: 0.8385 - learning_rate: 0.0010
# Epoch 159/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6296 - loss: 0.8321 - val_accuracy: 0.6314 - val_loss: 0.8379 - learning_rate: 0.0010
# Epoch 160/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6306 - loss: 0.8332 - val_accuracy: 0.6323 - val_loss: 0.8373 - learning_rate: 0.0010
# Epoch 161/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6203 - loss: 0.8387 - val_accuracy: 0.6328 - val_loss: 0.8367 - learning_rate: 0.0010
# Epoch 162/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6314 - loss: 0.8265 - val_accuracy: 0.6333 - val_loss: 0.8361 - learning_rate: 0.0010
# Epoch 163/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6215 - loss: 0.8342 - val_accuracy: 0.6342 - val_loss: 0.8355 - learning_rate: 0.0010
# Epoch 164/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6348 - loss: 0.8224 - val_accuracy: 0.6356 - val_loss: 0.8349 - learning_rate: 0.0010
# Epoch 165/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6395 - loss: 0.8234 - val_accuracy: 0.6361 - val_loss: 0.8343 - learning_rate: 0.0010
# Epoch 166/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6380 - loss: 0.8178 - val_accuracy: 0.6356 - val_loss: 0.8338 - learning_rate: 0.0010
# Epoch 167/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6334 - loss: 0.8185 - val_accuracy: 0.6356 - val_loss: 0.8332 - learning_rate: 0.0010
# Epoch 168/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6292 - loss: 0.8252 - val_accuracy: 0.6356 - val_loss: 0.8327 - learning_rate: 0.0010
# Epoch 169/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6385 - loss: 0.8125 - val_accuracy: 0.6366 - val_loss: 0.8321 - learning_rate: 0.0010
# Epoch 170/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6385 - loss: 0.8227 - val_accuracy: 0.6366 - val_loss: 0.8316 - learning_rate: 0.0010
# Epoch 171/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6249 - loss: 0.8316 - val_accuracy: 0.6375 - val_loss: 0.8310 - learning_rate: 0.0010
# Epoch 172/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6266 - loss: 0.8273 - val_accuracy: 0.6385 - val_loss: 0.8305 - learning_rate: 0.0010
# Epoch 173/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6451 - loss: 0.8110 - val_accuracy: 0.6385 - val_loss: 0.8299 - learning_rate: 0.0010
# Epoch 174/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6298 - loss: 0.8207 - val_accuracy: 0.6389 - val_loss: 0.8295 - learning_rate: 0.0010
# Epoch 175/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6360 - loss: 0.8196 - val_accuracy: 0.6385 - val_loss: 0.8290 - learning_rate: 0.0010
# Epoch 176/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6407 - loss: 0.8078 - val_accuracy: 0.6385 - val_loss: 0.8284 - learning_rate: 0.0010
# Epoch 177/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6399 - loss: 0.8123 - val_accuracy: 0.6375 - val_loss: 0.8280 - learning_rate: 0.0010
# Epoch 178/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6376 - loss: 0.8158 - val_accuracy: 0.6385 - val_loss: 0.8275 - learning_rate: 0.0010
# Epoch 179/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6372 - loss: 0.8102 - val_accuracy: 0.6389 - val_loss: 0.8270 - learning_rate: 0.0010
# Epoch 180/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6409 - loss: 0.8152 - val_accuracy: 0.6394 - val_loss: 0.8265 - learning_rate: 0.0010
# Epoch 181/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6445 - loss: 0.8102 - val_accuracy: 0.6399 - val_loss: 0.8260 - learning_rate: 0.0010
# Epoch 182/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6431 - loss: 0.8122 - val_accuracy: 0.6399 - val_loss: 0.8255 - learning_rate: 0.0010
# Epoch 183/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6320 - loss: 0.8061 - val_accuracy: 0.6408 - val_loss: 0.8250 - learning_rate: 0.0010
# Epoch 184/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6342 - loss: 0.8121 - val_accuracy: 0.6408 - val_loss: 0.8245 - learning_rate: 0.0010
# Epoch 185/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6393 - loss: 0.8093 - val_accuracy: 0.6413 - val_loss: 0.8240 - learning_rate: 0.0010
# Epoch 186/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6370 - loss: 0.8070 - val_accuracy: 0.6403 - val_loss: 0.8235 - learning_rate: 0.0010
# Epoch 187/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6427 - loss: 0.8155 - val_accuracy: 0.6408 - val_loss: 0.8230 - learning_rate: 0.0010
# Epoch 188/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6368 - loss: 0.8158 - val_accuracy: 0.6408 - val_loss: 0.8226 - learning_rate: 0.0010
# Epoch 189/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6407 - loss: 0.8042 - val_accuracy: 0.6408 - val_loss: 0.8221 - learning_rate: 0.0010
# Epoch 190/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6443 - loss: 0.8076 - val_accuracy: 0.6413 - val_loss: 0.8217 - learning_rate: 0.0010
# Epoch 191/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6437 - loss: 0.8173 - val_accuracy: 0.6417 - val_loss: 0.8214 - learning_rate: 0.0010
# Epoch 192/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6445 - loss: 0.8144 - val_accuracy: 0.6427 - val_loss: 0.8209 - learning_rate: 0.0010
# Epoch 193/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6439 - loss: 0.8062 - val_accuracy: 0.6432 - val_loss: 0.8206 - learning_rate: 0.0010
# Epoch 194/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6475 - loss: 0.8057 - val_accuracy: 0.6436 - val_loss: 0.8202 - learning_rate: 0.0010
# Epoch 195/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6383 - loss: 0.8054 - val_accuracy: 0.6436 - val_loss: 0.8198 - learning_rate: 0.0010
# Epoch 196/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6457 - loss: 0.8078 - val_accuracy: 0.6432 - val_loss: 0.8193 - learning_rate: 0.0010
# Epoch 197/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6566 - loss: 0.7896 - val_accuracy: 0.6436 - val_loss: 0.8189 - learning_rate: 0.0010
# Epoch 198/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6393 - loss: 0.8118 - val_accuracy: 0.6432 - val_loss: 0.8185 - learning_rate: 0.0010
# Epoch 199/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6455 - loss: 0.7987 - val_accuracy: 0.6427 - val_loss: 0.8180 - learning_rate: 0.0010
# Epoch 200/200
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6352 - loss: 0.8112 - val_accuracy: 0.6436 - val_loss: 0.8175 - learning_rate: 0.0010
#      Época      Loss  Val_Loss  Accuracy  Val_Accuracy
# 0  Primera  1.368312  1.170375  0.351673      0.367654
# 1   Última  0.811203  0.817511  0.635228      0.643630

# %%
yPred = modelo.predict(xTest)
yPred_classes = yPred.argmax(axis=1)

# Matriz de confusión
cm = confusion_matrix(yTest, yPred_classes)
class_names = ['Negativo', 'Neutro', 'Positivo']

# Graficar
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Matriz de Confusión")

plt.xlabel("Predicción")
plt.ylabel("Etiqueta real")

plt.show()
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Accuracy
plt.plot(resultado.history["accuracy"], label="Entrenamiento")
plt.plot(resultado.history["val_accuracy"], label="Validación")
plt.title("Evolución del Accuracy")
plt.xlabel("Época")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.plot(resultado.history["loss"], label="Entrenamiento")
plt.plot(resultado.history["val_loss"], label="Validación")
plt.title("Evolución de las Pérdidas")
plt.xlabel("Época")
plt.ylabel("Pérdida")
plt.legend()
plt.show()
