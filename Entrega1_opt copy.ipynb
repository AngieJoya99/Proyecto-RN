# %% [markdown]
# **Angie Carolina Joya Duarte - 2322609**
#
# **Sheila Marcela Valencia Chito - 2243011**

# %% [markdown]
# Tiene  como  objetivo  el  entrenamiento  y  evaluación  de  un  modelo  con  el  dataset
# seleccionado usando una arquitectura de Perceptrón Multicapa. condiciones de entrenamiento, evaluación, conclusiones

# %% [markdown]
# # Entrega 1 - Perceptrón Multicapa

# %% [markdown]
# Se escogió para este trabajo el dataset "Twitter US Airline Sentiment"

# %% [markdown]
# ## Importación del dataset

# %% [markdown]
# Importamos las librerías

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
from imblearn.under_sampling import NearMiss
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import RegexpTokenizer
import re

# %% [markdown]
# Importamos el dataset y lo almacenamos como un dataframe de pandas. Verificamos que no hayan datos faltantes y convertimos la salidas en números usando one hot encoding

# %%
path = os.path.join(os.getcwd(), "Tweets.csv")
dataset = pd.read_csv(path, usecols=[1, 5, 10])

print("Clasificación Original: ", dataset.airline_sentiment.unique(),"\n")

#Se reemplaza negative por 0, neutral por 1 y positive por 2
dataset["airline_sentiment"] = dataset["airline_sentiment"].replace({"negative" : 0, "neutral" : 1, "positive" : 2}).astype(int)

#dataset.describe(include='all')
dataset.info()
print("\nAerolíneas: ", dataset.airline.unique())
print("Clasificación one hot encoder: ", dataset.airline_sentiment.unique())
# Out:
# Clasificación Original:  ['neutral' 'positive' 'negative']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   airline_sentiment  14640 non-null  int64
#  1   airline            14640 non-null  object
#  2   text               14640 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 343.3+ KB
#
# Aerolíneas:  ['Virgin America' 'United' 'Southwest' 'Delta' 'US Airways' 'American']
# Clasificación one hot encoder:  [1 2 0]
# C:\Users\Univalle\AppData\Local\Temp\ipykernel_6184\879290016.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset["airline_sentiment"] = dataset["airline_sentiment"].replace({"negative" : 0, "neutral" : 1, "positive" : 2}).astype(int)

# %%
graphAirline = sns.countplot(x="airline", hue="airline", data=dataset, palette="Set2", legend=False)
total = len(dataset)

for p in graphAirline.patches:
    count = p.get_height() #frecuencia absoluta
    percent = 100 * count / total #frecuencia relativa
    
    graphAirline.annotate(f'{percent:.1f}%', # formato de texto
        (p.get_x() + p.get_width() / 2., count/2),  #posición
        ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 5),
        textcoords='offset points')
    
graphAirline.set_xlabel("Aerolínea")
graphAirline.set_ylabel("Instancias")
graphAirline.set_title("Distribución Porcentual de las Aerolíneas")


plt.show()

# %%
graphOutput = sns.countplot(x="airline_sentiment", hue="airline_sentiment",  data=dataset, palette="Set2", legend=False)
total = len(dataset)

for p in graphOutput.patches:
    count = p.get_height() #frecuencia absoluta
    percent = 100 * count / total #frecuencia relativa
    
    graphOutput.annotate(f'{percent:.1f}%', # formato de texto
        (p.get_x() + p.get_width() / 2., count/2),  #posición
        ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 5),
        textcoords='offset points')
    
ticks = graphOutput.get_xticks()
graphOutput.set_xticks(ticks)
graphOutput.set_xticklabels(["Negativo", "Neutro", "Positivo"])
graphOutput.set_xlabel("Sentimiento")
graphOutput.set_ylabel("Instancias")
graphOutput.set_title("Distribución Porcentual de los Sentimientos")

plt.show()

# %% [markdown]
# Como el dataset está compuesto por cadenas de texto, será pre procesado antes de iniciar el entrenamiento

# %%
nltk.download('stopwords')
palVacias = set(stopwords.words('english')) 
palRaiz = SnowballStemmer('english')
tokenizador = RegexpTokenizer(r"\b\w+(?:'\w+)?\b")
usuarios = r"@\w*"
hashtags = r"#(\w+)"
links = links = r"http\S+|www\.\S+"

def preprocesamiento (tweet, stem=True):
    tweet = re.sub(usuarios, "", tweet)
    tweet = re.sub(hashtags, r"\1", tweet)
    tweet = re.sub(r"\b(\w+)n't\b", "not", tweet, flags=re.IGNORECASE) #Para las negaciones
    tweet = re.sub(links, "", tweet)
    
    palabras = tokenizador.tokenize(tweet)
    texto = []
    for palabra in palabras: 
        palabra_lower = palabra.lower()
        # Conserva "no" aunque sea stopword
        if palabra_lower == "not" or palabra_lower == "no" or palabra_lower not in palVacias:
            if stem:
                texto.append(palRaiz.stem(palabra).lower())
            else:
                texto.append(palabra_lower)
    
    return tokenizador.tokenize(" ".join(texto))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Univalle\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Los enlaces se muestran como palabras: 'http', 'co', 'vhp2gtdwpk'
print(f"Texto Original: {dataset.text[39]}")
print(f"\nTexto Preprocesado: {preprocesamiento(dataset.text[39])}")
# Out:
# Texto Original: @VirginAmerica Your chat support is not working on your site: http://t.co/vhp2GtDWPk
#
# Texto Preprocesado: ['chat', 'support', 'not', 'work', 'site']

# %%
#Aplicar preprocesamiento a todo el dataset
dataset["token"] = dataset.text.map(preprocesamiento)
dataset.head()
# Out:
#    airline_sentiment         airline  \
# 0                  1  Virgin America
# 1                  2  Virgin America
# 2                  1  Virgin America
# 3                  0  Virgin America
# 4                  0  Virgin America
#
#                                                 text  \
# 0                @VirginAmerica What @dhepburn said.
# 1  @VirginAmerica plus you've added commercials t...
# 2  @VirginAmerica I didn't today... Must mean I n...
# 3  @VirginAmerica it's really aggressive to blast...
# 4  @VirginAmerica and it's a really big bad thing...
#
#                                                token
# 0                                             [said]
# 1                [plus, ad, commerci, experi, tacki]
# 2  [not, today, must, mean, need, take, anoth, trip]
# 3  [realli, aggress, blast, obnoxi, entertain, gu...
# 4                          [realli, big, bad, thing]

# %%
vectorizador = TfidfVectorizer(
  tokenizer=lambda x: x, 
    preprocessor=lambda x: x, 
    token_pattern=None,
    ngram_range=(1,2),  # unigrams + bigrams
    min_df=3, # ignora palabras rarísimas
    max_df=0.9
  )
matriz = vectorizador.fit_transform(dataset["token"])

from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler

svd = TruncatedSVD(n_components=300, random_state=42)
matriz_svd = svd.fit_transform(matriz)

# Escalar (normalización)
scaler = StandardScaler()
matriz_svd = scaler.fit_transform(matriz_svd)

dataset["rep"] = matriz_svd.tolist()
dataset.head()
# Out:
#    airline_sentiment         airline  \
# 0                  1  Virgin America
# 1                  2  Virgin America
# 2                  1  Virgin America
# 3                  0  Virgin America
# 4                  0  Virgin America
#
#                                                 text  \
# 0                @VirginAmerica What @dhepburn said.
# 1  @VirginAmerica plus you've added commercials t...
# 2  @VirginAmerica I didn't today... Must mean I n...
# 3  @VirginAmerica it's really aggressive to blast...
# 4  @VirginAmerica and it's a really big bad thing...
#
#                                                token  \
# 0                                             [said]
# 1                [plus, ad, commerci, experi, tacki]
# 2  [not, today, must, mean, need, take, anoth, trip]
# 3  [realli, aggress, blast, obnoxi, entertain, gu...
# 4                          [realli, big, bad, thing]
#
#                                                  rep
# 0  [-0.4436108992312125, -0.7270816566788405, -0....
# 1  [-0.4400674522902267, -0.817444374400045, -0.0...
# 2  [-0.20420856435639567, 0.3509935026227756, -0....
# 3  [-0.4197145267098829, -0.6603471258744055, -0....
# 4  [-0.38259301701733595, -0.603346062784163, -0....

# %% [markdown]
# Ahora, vamos a revisar la revisión porcentual de los datos para asegurarnos de que el conjunto sea representativo

# %% [markdown]
# La distribución de los datos no está balanceada. La aerolínea Virgin América tiene muchas menos instancias que las demás, y United tiene muchas más, así que implementamos la técnica del Submuestreo Near Miss para equilibrar los datos.

# %%
submuestreo = NearMiss()
x = np.vstack(dataset["rep"].values)
y = dataset["airline_sentiment"].values

xBal, yBal = submuestreo.fit_resample(x, y)
indicesBal = submuestreo.sample_indices_

datasetBal = dataset.iloc[indicesBal].copy().reset_index(drop=True)
datasetBal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7089 entries, 0 to 7088
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   airline_sentiment  7089 non-null   int64
#  1   airline            7089 non-null   object
#  2   text               7089 non-null   object
#  3   token              7089 non-null   object
#  4   rep                7089 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 277.0+ KB

# %%
graphOutput = sns.countplot(x="airline_sentiment", hue="airline_sentiment",  data=datasetBal, palette="Set2", legend=False)
total = len(datasetBal)

for p in graphOutput.patches:
    count = p.get_height() #frecuencia absoluta
    percent = 100 * count / total #frecuencia relativa
    
    graphOutput.annotate(f'{percent:.1f}%', # formato de texto
        (p.get_x() + p.get_width() / 2., count/2),  #posición
        ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 5),
        textcoords='offset points')
    
ticks = graphOutput.get_xticks()
graphOutput.set_xticks(ticks)
graphOutput.set_xticklabels(["Negativo", "Neutro", "Positivo"])
graphOutput.set_xlabel("Sentimiento")
graphOutput.set_ylabel("Instancias")
graphOutput.set_title("Distribución Porcentual de los Sentimientos del dataset Balanceado")

plt.show()

# %%
n = len(datasetBal)
cTrain = int(n*0.7) # 70% para entrenar y 30% para probar
cTest = n-cTrain
print(f"N = {n} | Tamaño entrenamiento = {cTrain} | Tamaño prueba = {cTest}")
trainData, testData = train_test_split(datasetBal, train_size=cTrain, test_size=cTest)
testData.head()
# Out:
# N = 7089 | Tamaño entrenamiento = 4962 | Tamaño prueba = 2127
#       airline_sentiment    airline  \
# 6166                  2      Delta
# 869                   0     United
# 3174                  1     United
# 5583                  2  Southwest
# 1061                  0      Delta
#
#                                                    text  \
# 6166  @JetBlue @amybruni @DIRECTTV but of course! :-...
# 869   @united feeling poor on the church-mouse level...
# 3174      @united can I get your service desk # at IAD?
# 5583  @SouthwestAir thanks so much just had to make ...
# 1061  @JetBlue aka take stuff out of the checked bag...
#
#                                                   token  \
# 6166                     [cours, bestdress, bluecarpet]
# 869   [feel, poor, church, mous, level, 180, dollar,...
# 3174                           [get, servic, desk, iad]
# 5583  [thank, much, make, cancel, flightlat, sent, u...
# 1061  [aka, take, stuff, check, bag, carri, extra, w...
#
#                                                     rep
# 6166  [-0.4873125144579168, -0.9971100748587813, -0....
# 869   [-0.3531965005831012, -0.37484663625889164, -0...
# 3174  [-0.28425906821678393, -0.07487407215524584, -...
# 5583  [1.7497161665074101, -0.5510987672047395, -0.1...
# 1061  [-0.29945158681027884, -0.17050321882422298, -...

# %%
# cantClases = 3
# sizeVocab = np.vstack(trainData.rep.values).shape[1]

# modelo = keras.Sequential([
#     layers.Input(shape=(sizeVocab,)),
#     layers.Dense(64, activation="relu", kernel_regularizer=regularizers.l2(0.001),),
#     layers.Dropout(0.4),
#     layers.Dense(32, activation="relu", kernel_regularizer=regularizers.l2(0.001),),
#     layers.Dropout(0.2),
#     layers.Dense(cantClases, activation="softmax")
# ])  
# opt = Adam(learning_rate=0.00001)
# modelo.compile(optimizer="adagrad", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

cantClases = 3
sizeVocab = np.vstack(trainData.rep.values).shape[1]
print(sizeVocab)

modelo = keras.Sequential([
    layers.Input(shape=(sizeVocab,)),
    layers.Dense(64, activation="relu", kernel_regularizer=regularizers.l2(0.0001),),
    layers.Dropout(0.3),
    layers.Dense(32, activation="relu", kernel_regularizer=regularizers.l2(0.0001),),
    layers.Dropout(0.2),
    layers.Dense(cantClases, activation="softmax")
])  
opt = Adam(learning_rate=0.00001)
modelo.compile(optimizer=opt, loss="sparse_categorical_crossentropy", metrics=["accuracy"])
# Out:
# 300

# %%
def entrenamiento (xTrain, yTrain, xTest, yTest, modelo, epocas, lote, es, rlr):
    history = modelo.fit(
        xTrain, yTrain,
        validation_data = (xTest, yTest),
        epochs = epocas,
        callbacks=[es, rlr],
        batch_size = lote,
        verbose = 1
    )
    return history

# %%
xTrain = np.array(trainData["rep"].to_list(), dtype="float32")
yTrain = trainData.airline_sentiment.values
xTest = np.array(testData["rep"].to_list(), dtype="float32")
yTest = testData.airline_sentiment.values
epocas = 130
lote = 32

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

es = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
rlr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-7)

resultado = entrenamiento(xTrain, yTrain, xTest, yTest, modelo, epocas, lote, es, rlr)

resultados = {
    "Época": ["Primera", "Última"],
    "Loss": [resultado.history["loss"][0], resultado.history["loss"][-1]],
    "Val_Loss": [resultado.history["val_loss"][0], resultado.history["val_loss"][-1]],
    "Accuracy": [resultado.history["accuracy"][0], resultado.history["accuracy"][-1]],
    "Val_Accuracy": [resultado.history["val_accuracy"][0], resultado.history["val_accuracy"][-1]],
}

tabla = pd.DataFrame(resultados)
print(tabla)
# Out:
# Epoch 1/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3432 - loss: 1.5250 - val_accuracy: 0.3258 - val_loss: 1.3462 - learning_rate: 1.0000e-05
# Epoch 2/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3392 - loss: 1.4893 - val_accuracy: 0.3216 - val_loss: 1.3243 - learning_rate: 1.0000e-05
# Epoch 3/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3434 - loss: 1.4656 - val_accuracy: 0.3244 - val_loss: 1.3038 - learning_rate: 1.0000e-05
# Epoch 4/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3456 - loss: 1.4450 - val_accuracy: 0.3286 - val_loss: 1.2855 - learning_rate: 1.0000e-05
# Epoch 5/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3426 - loss: 1.4239 - val_accuracy: 0.3300 - val_loss: 1.2691 - learning_rate: 1.0000e-05
# Epoch 6/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3501 - loss: 1.3979 - val_accuracy: 0.3329 - val_loss: 1.2550 - learning_rate: 1.0000e-05
# Epoch 7/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3499 - loss: 1.3854 - val_accuracy: 0.3413 - val_loss: 1.2418 - learning_rate: 1.0000e-05
# Epoch 8/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3555 - loss: 1.3600 - val_accuracy: 0.3432 - val_loss: 1.2301 - learning_rate: 1.0000e-05
# Epoch 9/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3605 - loss: 1.3507 - val_accuracy: 0.3479 - val_loss: 1.2194 - learning_rate: 1.0000e-05
# Epoch 10/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3648 - loss: 1.3447 - val_accuracy: 0.3503 - val_loss: 1.2095 - learning_rate: 1.0000e-05
# Epoch 11/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3563 - loss: 1.3356 - val_accuracy: 0.3559 - val_loss: 1.2005 - learning_rate: 1.0000e-05
# Epoch 12/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3581 - loss: 1.3318 - val_accuracy: 0.3606 - val_loss: 1.1919 - learning_rate: 1.0000e-05
# Epoch 13/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3658 - loss: 1.3099 - val_accuracy: 0.3634 - val_loss: 1.1838 - learning_rate: 1.0000e-05
# Epoch 14/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3710 - loss: 1.2781 - val_accuracy: 0.3681 - val_loss: 1.1764 - learning_rate: 1.0000e-05
# Epoch 15/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3781 - loss: 1.2949 - val_accuracy: 0.3695 - val_loss: 1.1692 - learning_rate: 1.0000e-05
# Epoch 16/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3736 - loss: 1.2671 - val_accuracy: 0.3714 - val_loss: 1.1626 - learning_rate: 1.0000e-05
# Epoch 17/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3746 - loss: 1.2652 - val_accuracy: 0.3733 - val_loss: 1.1563 - learning_rate: 1.0000e-05
# Epoch 18/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3779 - loss: 1.2559 - val_accuracy: 0.3771 - val_loss: 1.1501 - learning_rate: 1.0000e-05
# Epoch 19/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3781 - loss: 1.2553 - val_accuracy: 0.3775 - val_loss: 1.1443 - learning_rate: 1.0000e-05
# Epoch 20/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3888 - loss: 1.2388 - val_accuracy: 0.3818 - val_loss: 1.1388 - learning_rate: 1.0000e-05
# Epoch 21/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3793 - loss: 1.2389 - val_accuracy: 0.3832 - val_loss: 1.1337 - learning_rate: 1.0000e-05
# Epoch 22/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3920 - loss: 1.2231 - val_accuracy: 0.3879 - val_loss: 1.1288 - learning_rate: 1.0000e-05
# Epoch 23/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3966 - loss: 1.2140 - val_accuracy: 0.3912 - val_loss: 1.1240 - learning_rate: 1.0000e-05
# Epoch 24/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3964 - loss: 1.1966 - val_accuracy: 0.3912 - val_loss: 1.1195 - learning_rate: 1.0000e-05
# Epoch 25/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3855 - loss: 1.2088 - val_accuracy: 0.3949 - val_loss: 1.1149 - learning_rate: 1.0000e-05
# Epoch 26/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4041 - loss: 1.1930 - val_accuracy: 0.3982 - val_loss: 1.1107 - learning_rate: 1.0000e-05
# Epoch 27/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4065 - loss: 1.1769 - val_accuracy: 0.3996 - val_loss: 1.1065 - learning_rate: 1.0000e-05
# Epoch 28/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4027 - loss: 1.1923 - val_accuracy: 0.4006 - val_loss: 1.1024 - learning_rate: 1.0000e-05
# Epoch 29/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4123 - loss: 1.1736 - val_accuracy: 0.4020 - val_loss: 1.0983 - learning_rate: 1.0000e-05
# Epoch 30/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4031 - loss: 1.1813 - val_accuracy: 0.4067 - val_loss: 1.0945 - learning_rate: 1.0000e-05
# Epoch 31/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4190 - loss: 1.1519 - val_accuracy: 0.4123 - val_loss: 1.0909 - learning_rate: 1.0000e-05
# Epoch 32/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4212 - loss: 1.1547 - val_accuracy: 0.4175 - val_loss: 1.0872 - learning_rate: 1.0000e-05
# Epoch 33/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4057 - loss: 1.1710 - val_accuracy: 0.4213 - val_loss: 1.0835 - learning_rate: 1.0000e-05
# Epoch 34/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4279 - loss: 1.1399 - val_accuracy: 0.4236 - val_loss: 1.0801 - learning_rate: 1.0000e-05
# Epoch 35/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4216 - loss: 1.1396 - val_accuracy: 0.4274 - val_loss: 1.0768 - learning_rate: 1.0000e-05
# Epoch 36/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4176 - loss: 1.1507 - val_accuracy: 0.4330 - val_loss: 1.0736 - learning_rate: 1.0000e-05
# Epoch 37/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4359 - loss: 1.1342 - val_accuracy: 0.4386 - val_loss: 1.0703 - learning_rate: 1.0000e-05
# Epoch 38/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4313 - loss: 1.1271 - val_accuracy: 0.4419 - val_loss: 1.0672 - learning_rate: 1.0000e-05
# Epoch 39/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4347 - loss: 1.1216 - val_accuracy: 0.4452 - val_loss: 1.0642 - learning_rate: 1.0000e-05
# Epoch 40/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4365 - loss: 1.1173 - val_accuracy: 0.4466 - val_loss: 1.0613 - learning_rate: 1.0000e-05
# Epoch 41/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4359 - loss: 1.1150 - val_accuracy: 0.4480 - val_loss: 1.0585 - learning_rate: 1.0000e-05
# Epoch 42/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4236 - loss: 1.1264 - val_accuracy: 0.4537 - val_loss: 1.0556 - learning_rate: 1.0000e-05
# Epoch 43/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4369 - loss: 1.1063 - val_accuracy: 0.4579 - val_loss: 1.0529 - learning_rate: 1.0000e-05
# Epoch 44/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4361 - loss: 1.1011 - val_accuracy: 0.4598 - val_loss: 1.0503 - learning_rate: 1.0000e-05
# Epoch 45/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4422 - loss: 1.0989 - val_accuracy: 0.4612 - val_loss: 1.0477 - learning_rate: 1.0000e-05
# Epoch 46/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4520 - loss: 1.0853 - val_accuracy: 0.4654 - val_loss: 1.0450 - learning_rate: 1.0000e-05
# Epoch 47/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4571 - loss: 1.0875 - val_accuracy: 0.4683 - val_loss: 1.0424 - learning_rate: 1.0000e-05
# Epoch 48/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4472 - loss: 1.0940 - val_accuracy: 0.4725 - val_loss: 1.0399 - learning_rate: 1.0000e-05
# Epoch 49/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4512 - loss: 1.0891 - val_accuracy: 0.4748 - val_loss: 1.0375 - learning_rate: 1.0000e-05
# Epoch 50/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4502 - loss: 1.0751 - val_accuracy: 0.4781 - val_loss: 1.0351 - learning_rate: 1.0000e-05
# Epoch 51/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4577 - loss: 1.0747 - val_accuracy: 0.4781 - val_loss: 1.0327 - learning_rate: 1.0000e-05
# Epoch 52/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4625 - loss: 1.0715 - val_accuracy: 0.4838 - val_loss: 1.0304 - learning_rate: 1.0000e-05
# Epoch 53/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4625 - loss: 1.0649 - val_accuracy: 0.4852 - val_loss: 1.0281 - learning_rate: 1.0000e-05
# Epoch 54/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4617 - loss: 1.0628 - val_accuracy: 0.4857 - val_loss: 1.0258 - learning_rate: 1.0000e-05
# Epoch 55/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4692 - loss: 1.0607 - val_accuracy: 0.4875 - val_loss: 1.0236 - learning_rate: 1.0000e-05
# Epoch 56/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4716 - loss: 1.0500 - val_accuracy: 0.4899 - val_loss: 1.0213 - learning_rate: 1.0000e-05
# Epoch 57/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4696 - loss: 1.0545 - val_accuracy: 0.4937 - val_loss: 1.0191 - learning_rate: 1.0000e-05
# Epoch 58/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4647 - loss: 1.0685 - val_accuracy: 0.4969 - val_loss: 1.0170 - learning_rate: 1.0000e-05
# Epoch 59/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4704 - loss: 1.0524 - val_accuracy: 0.5016 - val_loss: 1.0149 - learning_rate: 1.0000e-05
# Epoch 60/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4736 - loss: 1.0429 - val_accuracy: 0.5016 - val_loss: 1.0128 - learning_rate: 1.0000e-05
# Epoch 61/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4764 - loss: 1.0450 - val_accuracy: 0.5040 - val_loss: 1.0108 - learning_rate: 1.0000e-05
# Epoch 62/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4676 - loss: 1.0601 - val_accuracy: 0.5045 - val_loss: 1.0088 - learning_rate: 1.0000e-05
# Epoch 63/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4716 - loss: 1.0460 - val_accuracy: 0.5059 - val_loss: 1.0068 - learning_rate: 1.0000e-05
# Epoch 64/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4833 - loss: 1.0356 - val_accuracy: 0.5078 - val_loss: 1.0048 - learning_rate: 1.0000e-05
# Epoch 65/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4877 - loss: 1.0265 - val_accuracy: 0.5101 - val_loss: 1.0029 - learning_rate: 1.0000e-05
# Epoch 66/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4696 - loss: 1.0431 - val_accuracy: 0.5115 - val_loss: 1.0009 - learning_rate: 1.0000e-05
# Epoch 67/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4863 - loss: 1.0357 - val_accuracy: 0.5134 - val_loss: 0.9991 - learning_rate: 1.0000e-05
# Epoch 68/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4752 - loss: 1.0363 - val_accuracy: 0.5134 - val_loss: 0.9972 - learning_rate: 1.0000e-05
# Epoch 69/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4855 - loss: 1.0246 - val_accuracy: 0.5153 - val_loss: 0.9954 - learning_rate: 1.0000e-05
# Epoch 70/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4861 - loss: 1.0254 - val_accuracy: 0.5167 - val_loss: 0.9936 - learning_rate: 1.0000e-05
# Epoch 71/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4911 - loss: 1.0155 - val_accuracy: 0.5172 - val_loss: 0.9919 - learning_rate: 1.0000e-05
# Epoch 72/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5008 - loss: 1.0134 - val_accuracy: 0.5214 - val_loss: 0.9900 - learning_rate: 1.0000e-05
# Epoch 73/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5073 - loss: 1.0086 - val_accuracy: 0.5223 - val_loss: 0.9883 - learning_rate: 1.0000e-05
# Epoch 74/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4978 - loss: 1.0100 - val_accuracy: 0.5214 - val_loss: 0.9866 - learning_rate: 1.0000e-05
# Epoch 75/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5075 - loss: 1.0039 - val_accuracy: 0.5242 - val_loss: 0.9848 - learning_rate: 1.0000e-05
# Epoch 76/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5101 - loss: 1.0100 - val_accuracy: 0.5261 - val_loss: 0.9831 - learning_rate: 1.0000e-05
# Epoch 77/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4980 - loss: 0.9994 - val_accuracy: 0.5289 - val_loss: 0.9814 - learning_rate: 1.0000e-05
# Epoch 78/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5052 - loss: 1.0059 - val_accuracy: 0.5322 - val_loss: 0.9797 - learning_rate: 1.0000e-05
# Epoch 79/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5161 - loss: 0.9997 - val_accuracy: 0.5341 - val_loss: 0.9781 - learning_rate: 1.0000e-05
# Epoch 80/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5169 - loss: 0.9962 - val_accuracy: 0.5369 - val_loss: 0.9764 - learning_rate: 1.0000e-05
# Epoch 81/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5083 - loss: 0.9944 - val_accuracy: 0.5393 - val_loss: 0.9747 - learning_rate: 1.0000e-05
# Epoch 82/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5169 - loss: 0.9907 - val_accuracy: 0.5393 - val_loss: 0.9730 - learning_rate: 1.0000e-05
# Epoch 83/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5272 - loss: 0.9881 - val_accuracy: 0.5402 - val_loss: 0.9713 - learning_rate: 1.0000e-05
# Epoch 84/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5212 - loss: 0.9829 - val_accuracy: 0.5411 - val_loss: 0.9697 - learning_rate: 1.0000e-05
# Epoch 85/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5252 - loss: 0.9843 - val_accuracy: 0.5430 - val_loss: 0.9681 - learning_rate: 1.0000e-05
# Epoch 86/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5268 - loss: 0.9840 - val_accuracy: 0.5444 - val_loss: 0.9665 - learning_rate: 1.0000e-05
# Epoch 87/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5270 - loss: 0.9776 - val_accuracy: 0.5440 - val_loss: 0.9649 - learning_rate: 1.0000e-05
# Epoch 88/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5238 - loss: 0.9825 - val_accuracy: 0.5449 - val_loss: 0.9632 - learning_rate: 1.0000e-05
# Epoch 89/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5304 - loss: 0.9787 - val_accuracy: 0.5472 - val_loss: 0.9616 - learning_rate: 1.0000e-05
# Epoch 90/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5373 - loss: 0.9731 - val_accuracy: 0.5482 - val_loss: 0.9600 - learning_rate: 1.0000e-05
# Epoch 91/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5288 - loss: 0.9710 - val_accuracy: 0.5520 - val_loss: 0.9583 - learning_rate: 1.0000e-05
# Epoch 92/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5367 - loss: 0.9673 - val_accuracy: 0.5534 - val_loss: 0.9567 - learning_rate: 1.0000e-05
# Epoch 93/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5246 - loss: 0.9783 - val_accuracy: 0.5534 - val_loss: 0.9552 - learning_rate: 1.0000e-05
# Epoch 94/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5421 - loss: 0.9638 - val_accuracy: 0.5538 - val_loss: 0.9537 - learning_rate: 1.0000e-05
# Epoch 95/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5218 - loss: 0.9715 - val_accuracy: 0.5552 - val_loss: 0.9521 - learning_rate: 1.0000e-05
# Epoch 96/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5466 - loss: 0.9557 - val_accuracy: 0.5562 - val_loss: 0.9506 - learning_rate: 1.0000e-05
# Epoch 97/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5385 - loss: 0.9609 - val_accuracy: 0.5585 - val_loss: 0.9489 - learning_rate: 1.0000e-05
# Epoch 98/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5427 - loss: 0.9616 - val_accuracy: 0.5581 - val_loss: 0.9473 - learning_rate: 1.0000e-05
# Epoch 99/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5419 - loss: 0.9528 - val_accuracy: 0.5595 - val_loss: 0.9458 - learning_rate: 1.0000e-05
# Epoch 100/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5488 - loss: 0.9528 - val_accuracy: 0.5618 - val_loss: 0.9443 - learning_rate: 1.0000e-05
# Epoch 101/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5324 - loss: 0.9621 - val_accuracy: 0.5628 - val_loss: 0.9428 - learning_rate: 1.0000e-05
# Epoch 102/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5508 - loss: 0.9485 - val_accuracy: 0.5632 - val_loss: 0.9413 - learning_rate: 1.0000e-05
# Epoch 103/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5457 - loss: 0.9467 - val_accuracy: 0.5637 - val_loss: 0.9398 - learning_rate: 1.0000e-05
# Epoch 104/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5490 - loss: 0.9444 - val_accuracy: 0.5646 - val_loss: 0.9382 - learning_rate: 1.0000e-05
# Epoch 105/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5427 - loss: 0.9586 - val_accuracy: 0.5651 - val_loss: 0.9368 - learning_rate: 1.0000e-05
# Epoch 106/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5522 - loss: 0.9401 - val_accuracy: 0.5656 - val_loss: 0.9353 - learning_rate: 1.0000e-05
# Epoch 107/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5635 - loss: 0.9411 - val_accuracy: 0.5665 - val_loss: 0.9338 - learning_rate: 1.0000e-05
# Epoch 108/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5572 - loss: 0.9409 - val_accuracy: 0.5689 - val_loss: 0.9323 - learning_rate: 1.0000e-05
# Epoch 109/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5548 - loss: 0.9410 - val_accuracy: 0.5698 - val_loss: 0.9308 - learning_rate: 1.0000e-05
# Epoch 110/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5619 - loss: 0.9368 - val_accuracy: 0.5712 - val_loss: 0.9293 - learning_rate: 1.0000e-05
# Epoch 111/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5611 - loss: 0.9377 - val_accuracy: 0.5717 - val_loss: 0.9279 - learning_rate: 1.0000e-05
# Epoch 112/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5548 - loss: 0.9400 - val_accuracy: 0.5722 - val_loss: 0.9265 - learning_rate: 1.0000e-05
# Epoch 113/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5607 - loss: 0.9306 - val_accuracy: 0.5736 - val_loss: 0.9250 - learning_rate: 1.0000e-05
# Epoch 114/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5669 - loss: 0.9262 - val_accuracy: 0.5750 - val_loss: 0.9236 - learning_rate: 1.0000e-05
# Epoch 115/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5693 - loss: 0.9254 - val_accuracy: 0.5750 - val_loss: 0.9222 - learning_rate: 1.0000e-05
# Epoch 116/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5732 - loss: 0.9251 - val_accuracy: 0.5755 - val_loss: 0.9209 - learning_rate: 1.0000e-05
# Epoch 117/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5854 - loss: 0.9061 - val_accuracy: 0.5759 - val_loss: 0.9195 - learning_rate: 1.0000e-05
# Epoch 118/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5768 - loss: 0.9134 - val_accuracy: 0.5773 - val_loss: 0.9181 - learning_rate: 1.0000e-05
# Epoch 119/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5697 - loss: 0.9160 - val_accuracy: 0.5792 - val_loss: 0.9167 - learning_rate: 1.0000e-05
# Epoch 120/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5671 - loss: 0.9169 - val_accuracy: 0.5802 - val_loss: 0.9153 - learning_rate: 1.0000e-05
# Epoch 121/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5726 - loss: 0.9239 - val_accuracy: 0.5806 - val_loss: 0.9140 - learning_rate: 1.0000e-05
# Epoch 122/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5778 - loss: 0.9108 - val_accuracy: 0.5816 - val_loss: 0.9125 - learning_rate: 1.0000e-05
# Epoch 123/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5776 - loss: 0.9134 - val_accuracy: 0.5825 - val_loss: 0.9111 - learning_rate: 1.0000e-05
# Epoch 124/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5701 - loss: 0.9100 - val_accuracy: 0.5839 - val_loss: 0.9097 - learning_rate: 1.0000e-05
# Epoch 125/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5685 - loss: 0.9187 - val_accuracy: 0.5839 - val_loss: 0.9085 - learning_rate: 1.0000e-05
# Epoch 126/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5820 - loss: 0.9055 - val_accuracy: 0.5863 - val_loss: 0.9071 - learning_rate: 1.0000e-05
# Epoch 127/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5792 - loss: 0.9019 - val_accuracy: 0.5872 - val_loss: 0.9057 - learning_rate: 1.0000e-05
# Epoch 128/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5871 - loss: 0.8938 - val_accuracy: 0.5877 - val_loss: 0.9043 - learning_rate: 1.0000e-05
# Epoch 129/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5788 - loss: 0.8960 - val_accuracy: 0.5877 - val_loss: 0.9029 - learning_rate: 1.0000e-05
# Epoch 130/130
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5915 - loss: 0.8971 - val_accuracy: 0.5905 - val_loss: 0.9015 - learning_rate: 1.0000e-05
#      Época      Loss  Val_Loss  Accuracy  Val_Accuracy
# 0  Primera  1.525010  1.346155  0.343208      0.325811
# 1   Última  0.897093  0.901471  0.591495      0.590503

# %%
yPred = modelo.predict(xTest)
yPred_classes = yPred.argmax(axis=1)

# Matriz de confusión
cm = confusion_matrix(yTest, yPred_classes)
class_names = ['Negativo', 'Neutro', 'Positivo']

# Graficar
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Matriz de Confusión")

plt.xlabel("Predicción")
plt.ylabel("Etiqueta real")

plt.show()
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Accuracy
plt.plot(resultado.history["accuracy"], label="Entrenamiento")
plt.plot(resultado.history["val_accuracy"], label="Validación")
plt.title("Evolución del Accuracy")
plt.xlabel("Época")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.plot(resultado.history["loss"], label="Entrenamiento")
plt.plot(resultado.history["val_loss"], label="Validación")
plt.title("Evolución de las Pérdidas")
plt.xlabel("Época")
plt.ylabel("Pérdida")
plt.legend()
plt.show()
